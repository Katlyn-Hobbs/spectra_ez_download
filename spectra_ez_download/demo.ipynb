# %%
import ez_spectral_analysis as ezpz
import os

path_to_fits_files ='data/s2d/' 
fits_files = os.listdir(path_to_fits_files)

# Read .fits data
# ---------------------------------------------------------------------------
wavelength, flux = ezpz.spectra_read(path=path_to_fits_files+fits_files[0])
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
# Plot data for selected orders:
# ------------------------------
ezpz.plot_raw_data(path=path_to_fits_files+fits_files[0], orders=[16, 17, 18, 19, 20])

# %%
# Mormalize spectra for selected orders and plot them 
# ------------------------------
wl, flux = ezpz.continuum_norm(path=path_to_fits_files+fits_files[0], 
                          plot=True, median_window=3, orders=[8, 16,17, 18])
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# ...
