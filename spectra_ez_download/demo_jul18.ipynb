# %%
from spectra_ez_download import ez_spectral_analysis as ezpz
import os

filepath = 'spectra_ez_download_git/spectra_ez_download/data/s2d/r.HARPN.2015-07-29T09-28-46.751_S2D_A.fits'
print(filepath)

spec = ezpz.ez_spectral_analysis(path=filepath, instrument='HARPS-N', plot=True)
spec.spectra_read()
spec.plot_raw_data()
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# spectra_ez_download_git/spectra_ez_download/data/s2d/r.HARPN.2015-07-29T09-28-46.751_S2D_A.fits

# %%
wls, norm_fluxes = spec.continuum_norm()
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
spec = ezpz.ez_spectral_analysis(path=filepath, instrument='HARPS-N', plot=False)
wl_berv, flux_berv = spec.BC_correction()
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# 3 3
# [4314.71781029 4314.73153315 4314.74525508 ... 4363.10537288 4363.1152829
#  4363.12519199]
# [4345.52487146 4345.53869356 4345.55251472 ... 4394.26280258 4394.27278422
#  4394.28276491]
# [4376.7748759  4376.78879907 4376.80272131 ... 4425.86845512 4425.87850965
#  4425.88856322]

# %%
spec.interpolation(template='spectra_ez_download_git/spectra_ez_download/data/s2d/r.HARPN.2015-07-29T09-28-46.751_S2D_A.fits')
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# (array([[3875.16291003, 3875.1752115 , 3875.18751214, ..., 3918.54605433,
#          3918.5549398 , 3918.56382443],
#         [3899.99187738, 3900.00426053, 3900.01664284, ..., 3943.65967242,
#          3943.66861605, 3943.67755883],
#         [3925.14343107, 3925.15589503, 3925.16835815, ..., 3969.0972346 ,
#          3969.10623676, 3969.11523807],
#         ...,
#         [6684.17397492, 6684.19531649, 6684.21665662, ..., 6759.43754893,
#          6759.45297437, 6759.46839836],
#         [6758.41013645, 6758.43171275, 6758.45328759, ..., 6834.50965904,
#          6834.52525611, 6834.54085171],
#         [6834.31222017, 6834.33403902, 6834.3558564 , ..., 6911.26805182,
#          6911.28382526, 6911.29959723]], dtype='>f8'),
#  [array([-2.04946091e+11, -2.04928885e+11, -2.04911681e+11, ...,
#          -1.50057211e+11, -1.50047115e+11, -1.50037021e+11]),
#   array([-1.87610911e+10, -1.87595263e+10, -1.87579616e+10, ...,
#          -1.37661286e+10, -1.37652091e+10, -1.37642898e+10]),
#   array([-5.88492812e+11, -5.88444092e+11, -5.88395378e+11, ...,
#          -4.32856886e+11, -4.32828214e+11, -4.32799545e+11])])
